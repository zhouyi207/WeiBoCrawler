# %% [markdown]
# ### 配置 .toml 文件

# %%
import toml

cookies = {
    "SCF": "AnQhEA08TUG9ln2r7R0-cHMvj3KTSZb-85kfIcXTHqooYhjTcn-UkaGS5792LpSqqbJApBlXrIheowZ1k4aYR1Q.",
    "SUB": "_2A25Kkj8dDeRhGeFJ4lIT9CzNyj6IHXVp7j7VrDV8PUNbmtAYLVT5kW9NfsmQ4UzJuUOhUQbYBkUvv3HADVVzl9Ig",
    "SUBP": "0033WrSXqPxfM725Ws9jqgMF55529P9D9W5Oj.LmOvr7_7fS8d6lYxiZ5JpX5KzhUgL.FoMN1K5EShzpeKz2dJLoIp7LxKML1KBLBKnLxKqL1hnLBoMNS0.7eoBEeK2E",
    "ALF": "02_1740495949",
    "SINAGLOBAL": "970667482772.5692.1737903974414",
    "_s_tentry": "-",
    "Apache": "6816769468273.411.1738037552250",
    "ULV": "1738037552254:3:3:3:6816769468273.411.1738037552250:1737957449024",
    "XSRF-TOKEN": "11rI6hKDuc3K5G2ezF4z0hBS",
    "PC_TOKEN": "5244ffa483",
    "WBPSESS": "2bPq4LTfaY-EnTnt8h5hWX9KGoz50scMNqd4lpDCT8IiCLnpv2C9Z_Kk8JVbYkIyBQ0eFNYccRFpnV_A6ntYby9mRTSp4yVHVscMtbb6neav_FRsiuVo3dDFXhgFIDTEunS8nK_U_4EmshtOSYLo3w=="
}

print(toml.dumps(cookies))

# %% [markdown]
# ### 解析请求

# %%
from tinydb import TinyDB
from WeiBoCrawler.util import database_config

# %%
db = TinyDB(database_config.list)

# %%
db.tables()
# Out:
# {'#姜萍已达到数学系本科生的水平#'}

# %%
table_name = "#姜萍已达到数学系本科生的水平#"
table = db.table(table_name)

# %%
from pathlib import Path

# %%
Path(__file__).parent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Path(__file__).parent
#
# NameError: name '__file__' is not defined
