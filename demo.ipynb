# %%
from SourceCode.pack.database import db_list
import pandas as pd


items = db_list.table("#姜萍已达到数学系本科生的水平#")
df = pd.DataFrame(items)

df
# Out:
#                   mid         uid personal_name  \
# 0    5096904217856018  2035895904        椒江叶Sir
# 1    5045314535297572  5588388976           最人物
# 2    5045260761957739  1644114654           新京报
# 3    5045304585359320  3167462347           笔默君
# 4    5045282662780046  6085180400          罐装冷水
# ..                ...         ...           ...
# 208  5045482600534552  6146364360      人贵有自知-文宇
# 209  5045479094618920  1704775054         攀枝花公安
# 210  5045477315185480  6871954018          _岚汐_
# 211  5045301635454153  7893021491       碗盆酱酱ovo
# 212  5045282776028468  1163218074           余丰慧
#
#                                          personal_href  \
# 0    https://weibo.com/2035895904?refer_flag=100103...
# 1    https://weibo.com/5588388976?refer_flag=100103...
# 2    https://weibo.com/1644114654?refer_flag=100103...
# 3    https://weibo.com/3167462347?refer_flag=100103...
# 4    https://weibo.com/6085180400?refer_flag=100103...
# ...

# %%
import re

s = "https://weibo.com/7893021491/Oj0v9mSSd?refer_f..."

re.search(r"/(\w*)\?", s).group(1)
# Out:
# 'Oj0v9mSSd'

# %%
# Out:
# '/weibo.com/7893021491/Oj0v9mSSd'

# %%
r = [re.search(r"/(\w*)\?", item).group(1) for item in df["weibo_href"].values]
print(r)
# Out:
# ['OEEV7wXHY', 'Oj0PXme8I', 'OiZre8dir', 'Oj0zUmucE', 'Oj00ybFds', 'Oj18tlqkf', 'Oj0Bg4v3d', 'Oj45yl6ur', 'Oj4HO1IrL', 'Oj5cxg2BF', 'Oj0O9uqNY', 'Oj8diA5Cy', 'Ojfeevno5', 'Oj8NcmH46', 'OFrC10SjD', 'OF7yZin9y', 'OENCBx1d3', 'OEN6K6UZi', 'OEHVExfdF', 'OEHAiaNmj', 'OEyCC6XUU', 'OEHda68aH', 'OEGnSjKz9', 'OEEbgiue6', 'OEBxCkT93', 'OEB6c386R', 'OEB3ubAld', 'OEzx35ziq', 'OExXyvm9u', 'OExSO0NwR', 'OExDS362r', 'OEx5RuzM1', 'OEwW7jk3z', 'OEwSKABQT', 'OEwFHtTxD', 'OEwFBhFEe', 'OEwEupvF7', 'OEwu4sLb3', 'OEws2De8S', 'OD2LH5AS4', 'OALhwgk3L', 'OzSIitvQX', 'Ovorck7Nx', 'OsPxkawcf', 'OpdKGh5Ue', 'OnS1itKvR', 'OmDhFdd4b', 'Om97njrjv', 'OlhVmcko6', 'OleJWjWMV', 'Ol7KvipSZ', 'Ol7bJlzdm', 'OkYKjxbX2', 'OkYlJCENy', 'OkXgvcUq0', 'OkVbOwnkz', 'OkCYwst1P', 'OkBtdCBZj', 'Oks8yDEsL', 'OknS6nZTZ', 'OkjNc3Gah', 'Okh1b1YeY', 'OkdDViiDG', 'OkcNz0LQe', 'OkbUZAmjo', 'Ok9EgljZd', 'Ok82qByPR', 'Ok5QqmsgR', 'Ok4J4eKAy', 'Ok2iMroBg', 'OjYT5fin7', 'OjYD7fQJN', 'OjVJ5aUzI', 'OjY3XghTF', 'OjRPDFViM', 'OjRzT67HP', 'OjQwT0WT
# ...

# %%
len(r)
# Out:
# 213
